# %%
# Importing python library
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import numpy as np
import seaborn as sns

# %%
# Read in csv file to each playlist and graph each attribute to spot differences. 
# I am reading in my happy and euphonious playlists.

pop = pd.read_csv("pop2.csv")
jazz = pd.read_csv("jazz2.csv")
rock = pd.read_csv("rock2.csv")
edm = pd.read_csv("edm2.csv")


# plt.plot(mixed.energy, color='blue')
# plt.plot(mixed.valence, color='red')
# mixed['danceability']=mixed['danceability'].astype(int)
pop.isnull().values.any()
jazz.isnull().values.any()
rock.isnull().values.any()
edm.isnull().values.any()

plt.figure(figsize=(10, 5))

plt.plot(pop.energy, label="Pop", color='blue')
plt.plot(jazz.energy, label="Jazz", color='red')
plt.plot(rock.energy, label="Rock", color='green')
plt.plot(edm.energy, label="EDM", color='brown')
plt.legend()

plt.xlabel("Mixed song")
plt.ylabel("energy intensity")
plt.title("energy intensity across all songs in both playlists")

plt.savefig("music_energy.jpg")

# %%
plt.figure(figsize=(10, 5))

plt.plot(pop.danceability, label="Pop", color='blue')
plt.plot(jazz.danceability, label="Jazz", color='red')
plt.plot(rock.danceability, label="Rock", color='green')
plt.plot(edm.danceability, label="EDM", color='brown')
plt.legend()

plt.xlabel("Mixed song")
plt.ylabel("danceability intensity")
plt.title("danceability intensity across all songs in both playlists")

plt.savefig("music_danceability.jpg")

# %%
plt.figure(figsize=(10, 5))

plt.plot(pop.valence, label="Pop", color='blue')
plt.plot(jazz.valence, label="Jazz", color='red')
plt.plot(rock.valence, label="Rock", color='green')
plt.plot(edm.valence, label="EDM", color='brown')
plt.legend()

plt.xlabel("Mixed song")
plt.ylabel("valence intensity")
plt.title("valence intensity across all songs in both playlists")

plt.savefig("music_valence.jpg")

# %%
plt.figure(figsize=(10, 5))

plt.plot(pop.instrumentalness, label="Pop", color='blue')
plt.plot(jazz.instrumentalness, label="Jazz", color='red')
plt.plot(rock.instrumentalness, label="Rock", color='green')
plt.plot(edm.instrumentalness, label="EDM", color='brown')
plt.legend()

plt.xlabel("Mixed song")
plt.ylabel("instrumentalness intensity")
plt.title("instrumentalness intensity across all songs in both playlists")

plt.savefig("music_instrumentalness.jpg")

# %%
plt.figure(figsize=(10, 5))

plt.plot(pop.acousticness, label="Pop", color='blue')
plt.plot(jazz.acousticness, label="Jazz", color='red')
plt.plot(rock.acousticness, label="Rock", color='green')
plt.plot(edm.acousticness, label="EDM", color='brown')
plt.legend()

plt.xlabel("Mixed song")
plt.ylabel("acousticness intensity")
plt.title("acousticness intensity across all songs in both playlists")

plt.savefig("music_acousticness.jpg")
