# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
music_genres = pd.read_csv("data_by_genres.csv")
music_genres
# Out:
#       mode                  genres  acousticness  danceability   duration_ms  \
# 0        1  21st century classical      0.979333      0.162883  1.602977e+05
# 1        1                   432hz      0.494780      0.299333  1.048887e+06
# 2        1                   8-bit      0.762000      0.712000  1.151770e+05
# 3        1                      []      0.651417      0.529093  2.328809e+05
# 4        1              a cappella      0.676557      0.538961  1.906285e+05
# ...    ...                     ...           ...           ...           ...
# 2968     1                    zolo      0.222625      0.547082  2.580991e+05
# 2969     0                 zouglou      0.161000      0.863000  2.063200e+05
# 2970     1                    zouk      0.263261      0.748889  3.060728e+05
# 2971     0            zurich indie      0.993000      0.705667  1.984173e+05
# 2972     1                  zydeco      0.421038      0.629409  1.716717e+05
#
# ...

# %%
music_genres.loc[music_genres["genres"] == "[]"]
# Out:
#    mode genres  acousticness  danceability   duration_ms    energy  \
# 3     1     []      0.651417      0.529093  232880.89025  0.419146
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 3          0.205309  0.218696 -12.288965     0.107872  112.857352  0.513604
#
#    popularity  key
# 3   20.859882    7

# %%
music_genres.columns
# Out:
# Index(['mode', 'genres', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
music_genres["genres"].value_counts()
# Out:
# 21st century classical    1
# north carolina roots      1
# nordic soundtrack         1
# norman ok indie           1
# norsk lovsang             1
#                          ..
# ethio-jazz                1
# ethiopian pop             1
# ethnomusicology           1
# ethnotronica              1
# zydeco                    1
# Name: genres, Length: 2973, dtype: int64
